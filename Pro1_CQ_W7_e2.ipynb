# %% [markdown]
# # Network construction & Community detection--Twitter data

# %% [markdown]
# ### We are given the data from tweeter, recording users' ID and the time and location when they post anything. Our basic idea is to construct a network where we observe the relation among places by analyzing people's activities near each location, trying to detect grouping communities and distinguish weak links from strong ones.

# %% [markdown]
# ## Step 1,  load the necessary data from our own module *CommDetect* with weekdays/weekend categories

# %%
# %pwd
# Out:
# u'/Users/CQ/Documents/Project1'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from combo import combo
from CommDetect import CommDetect as CD
# %pylab inline

PWD = '/Users/CQ/Documents/Project1'
# Out:
# Failed `CDLL(/Library/Frameworks/GEOS.framework/Versions/Current/GEOS)`
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Step 2, construct a network with the probability, or equivalently, the weight of link(a,b) defined as
# ### $$link(a,b) = \Sigma_c\frac{t(c,a) \cdot (t(c,b)-\delta(a,b))}{T \cdot (t(c)-1)}$$
# ### where
# * *t(c,a)* denotes the total number of tweets that user *c* has posted at location (in our case, zipcode) *a*
# * $t(c) = \Sigma_a t(c,a)$
# * $T = \Sigma_c t(c)$

# %% [markdown]
# ### We store our naive networks in **Net1** while **Net2** is for probabilistic networks, same notion behind **Graph1** and **Graph2**

# %%
Net1, Net2 = range(4), range(4)
Graph, Graph1, Graph2 = range(4), range(4), range(4)
LABEL = ['All ','Week','Satur','Sun']

# %% [markdown]
# ### The following graphs are not necessary for map plotting--we have partition dictionary for that. These graphs are only used for modularity calculation.

# %%
for i in range(4):
    Net1[i] = pd.read_csv(PWD + '/Network1/Network of '+LABEL[i]+'days.csv').iloc[:,1:]
    Net2[i] = pd.read_csv(PWD + '/Network2/Network2 of '+LABEL[i]+'days.csv').iloc[:,1:]
    Graph[i] = CD.Graph_build(Net1,i,False)
    Graph1[i] = CD.make_directed_and_weighted(Graph[i])
    Graph2[i] = CD.Graph_build(Net2,i,True)

# %% [markdown]
# ## Step 3, proceed to community detection

# %%
N_CP4, P_CP4 = range(4), range(4)
for i in range(4):
    N_CP4[i] = pd.read_csv(PWD + '/Network1/[Naive]Combo of '+LABEL[i]+'days.csv')
    P_CP4[i] = pd.read_csv(PWD + '/Network2/[Prob]Combo of '+LABEL[i]+'days.csv')
    N_CP4[i] = dict(zip(N_CP4[i].ZipCode, N_CP4[i].Part))
    P_CP4[i] = dict(zip(P_CP4[i].ZipCode, P_CP4[i].Part))

# %%
fig1 = plt.figure(num = 1, figsize = (20,15))
plt.suptitle('Figure 1(Naive Network)\nCommunity Detection by Combo method--4', fontweight="bold", size=18)
for i in range(4):
    CD.PlotMapPart(fig1, N_CP4[i], date_index=i, title = LABEL[i]+'days, modularity %f' %combo.modularity(Graph1[i],N_CP4[i]))

# %%
fig2 = plt.figure(num = 2, figsize = (20,15))
plt.suptitle('Figure 2(Probabilistic network)\nCommunity Detection by Combo method--4', fontweight="bold", size=18)
for i in range(4):
    CD.PlotMapPart(fig2, P_CP4[i], date_index=i, title = LABEL[i]+', modularity %f' %combo.modularity(Graph2[i],P_CP4[i]))

# %% [markdown]
# ## Step 4, some data visualization and demonstration

# %% [markdown]
# ### A) First glance, twitter users' daily activities, with weekends highlighted. This confirms that we do miss some data here as many days having "zero" activity which is clearly against common sense.

# %%
CD.DailyActivity()

# %% [markdown]
# ### B) Top places (zip codes) with highest amount of tweets, marked in map

# %%
PR1, PR2, UGraph1_PR, UGraph2_PR = range(4), range(4), range(4), range(4)
for i in range(4):
    PR2[i] = CD.as_undirected(Graph2[i])
    UGraph1_PR[i] = list(nx.connected_component_subgraphs(Graph[i], copy=True))[0]
    PR1[i] = nx.pagerank(UGraph1_PR[i],0.85)
    UGraph2_PR[i] = list(nx.connected_component_subgraphs(PR2[i], copy=True))[0]
    PR2[i] = nx.pagerank(UGraph2_PR[i],0.85)
# Out:
# /Users/CQ/anaconda/lib/python2.7/site-packages/networkx-1.9.1-py2.7.egg/networkx/generators/stochastic.py:41: UserWarning: zero out-degree for node 11005.0
#   warnings.warn('zero out-degree for node %s'%u)
# /Users/CQ/anaconda/lib/python2.7/site-packages/networkx-1.9.1-py2.7.egg/networkx/generators/stochastic.py:41: UserWarning: zero out-degree for node 11001.0
#   warnings.warn('zero out-degree for node %s'%u)

# %% [markdown]
# ### You can either change the number of "Top" directly or change TopPercent instead

# %%
TopPercent = 10
Top = len(CD.PLACES) * TopPercent / 100
Top
# Out:
# 23

# %%
TopZipNaive, TopZipProb = range(4), range(4)
fig4 = plt.figure(num = 4, figsize = (15,10))
Color = matplotlib.cm.gist_heat(linspace(0,1,Top*2))
plt.suptitle('Naive Network\nTop %d%% zipcodes with their page rank value'%TopPercent, fontweight="bold", size=18)
for i in range(4):
    TopZipNaive[i] = CD.TopZipCode(fig4, PR1[i], i, Color, Top)

# %%
fig5 = plt.figure(num = 5, figsize = (15,10))
plt.suptitle('Probabilistic Network\nTop %d%% zipcodes with their page rank value'%TopPercent, fontweight="bold", size=18)
for i in range(4):
    TopZipProb[i] = CD.TopZipCode(fig5, PR2[i], i, Color, Top)

# %% [markdown]
# ## Next we try page rank algorithm to see if it can provide anything interesting, we will compare our probabilistic network with naive networks

# %%
fig6 = plt.figure(num = 6, figsize = (20,15))
plt.suptitle('Naive network\nCommunity Detection by Page Rank\n(Top %d%% marked as black)'%TopPercent, fontweight="bold", size=18)
for i in range(4):
    CD.PlotPageRankPart(fig6, PR1[i], TopZipNaive, date_index=i, title = LABEL[i]+'days')

# %%
fig7 = plt.figure(num = 7, figsize = (20,15))
plt.suptitle('Probabilistic network\nCommunity Detection by Page Rank\n(Top %d%% marked as black)'%TopPercent, fontweight="bold", size=18)
for i in range(4):
    CD.PlotPageRankPart(fig7, PR2[i], TopZipProb, date_index=i, title = LABEL[i]+'days')

# %% [markdown]
# ### C) Some demographic data of New York gathered in 2014

# %%
Demo_NY = CD.ReadDemoNY()

# %% [markdown]
# ### Since the demographic data provides only number regarding population, and the area of each territory plays a more crucial role here, comparing populatin doesn't make much sense. Instead, we normalize it by dividing the population, and then compare the percentage.
# ### The formulae for such weighted average are:
# $$mean=\frac{\sum_z [p(z) \cdot pop(z)]}{\sum_z pop(z)}$$
# $$std=\sqrt{\frac{\sum_z [(p(z)-mean)^2 \cdot pop(z)]}{\sum_z pop(z)}}$$
# ### where p(z), pop(z) denote the percentage and population, respectively

# %%
CD.HighlightFeatures(Demo_NY, CD.population, P_CP4, CD.legend_pop,'Population')

# %%
CD.HighlightFeatures(Demo_NY, CD.race, P_CP4, CD.legend_race,'Race')

# %%
CD.HighlightFeatures(Demo_NY, CD.households, P_CP4, CD.legend_households,'Household')

# %%
CD.HighlightFeatures(Demo_NY, CD.education, P_CP4, CD.legend_edu,'Education')

# %%
CD.HighlightFeatures(Demo_NY, CD.insurance, P_CP4, CD.legend_insur,'Insurance')

# %%
CD.HighlightFeatures(Demo_NY, CD.commute_time, P_CP4, CD.legend_commute_time,'Communte Time')

# %%
CD.HighlightFeatures(Demo_NY, CD.income, P_CP4, CD.legend_income,'Income')

# %%
CD.HighlightFeatures(Demo_NY, CD.house_price, P_CP4, CD.legend_house_price,'Housing Price')

# %%
CD.HighlightFeatures(Demo_NY, CD.rent_price, P_CP4, CD.legend_rent_price,'Rent Price')

# %% [markdown]
# # Next we highlight some features, for example, the price level and education level among 4 selected commuties

# %% [markdown]
# ## First we draw the map again, then show features with corespondent color

# %%
fig8 = plt.figure(num = 8, figsize = (15,12))
CD.PlotMapPart(fig8, P_CP4[0], size = 111, alpha = 0.7, cmap = 'spectral')

# %%
CD.HighlightFeatures(Demo_NY, CD.race, P_CP4, CD.legend_race,'Race', by_feature=1)

# %% [markdown]
# #### Manhattan has a lot of labor force and people with no family, with lowest number of single-parent
# #### People with children tend to live outside of the city, where Brooklyn and State Island are the most popular places

# %%
CD.HighlightFeatures(Demo_NY, CD.households, P_CP4, CD.legend_households,'Household', by_feature=1)

# %% [markdown]
# ### Manhattan has unshakable advantage in higher education

# %%
CD.HighlightFeatures(Demo_NY, CD.education, P_CP4, CD.legend_edu,'Education', by_feature=1)

# %% [markdown]
# ## Next picture tells us two things:
# 1. Since most working places are located in Manhattan, it's understandable why they have the most people who work at home
# 2. While many people choose to live outside out the city, they are constantly suffering long time commute (>40 minutes), which, in another way, highlights Manhattan's business-concentration

# %%
CD.HighlightFeatures(Demo_NY, CD.commute_time, P_CP4, CD.legend_commute_time,'Communte Time', by_feature=1)

# %% [markdown]
# ## The following pictures showcase Manhattan's price level from three prospectives
# ## Basically, Bronx and Queens are poorest, while Manhattan being the richest community without a doubt, Staten Island and Brooklyn are just in the middle

# %%
CD.HighlightFeatures(Demo_NY, CD.income, P_CP4, CD.legend_income,'Income', by_feature=1)

# %%
CD.HighlightFeatures(Demo_NY, CD.house_price, P_CP4, CD.legend_house_price,'Housing Price', by_feature=1)

# %%
CD.HighlightFeatures(Demo_NY, CD.rent_price, P_CP4, CD.legend_rent_price,'Rent Price', by_feature=1)

# %%
CD.HighlightFeatures(Demo_NY, CD.insurance, P_CP4, CD.legend_insur,'House Type', by_feature=1)

# %% [markdown]
# ### Next, we know that midtown Manhattan possess a lot of vacant house, not surprising consider its highest rent price/house price

# %%
CD.HighlightFeatures(Demo_NY, CD.type_house, P_CP4, CD.legend_housetype,'House Type', by_feature=1)

# %% [markdown]
# ## Finally, we extract and gather some of those most conspicuous cases and put them together for demonstration

# %%
income_per_capita=['SE_T083_001']
selection = CD.education[-3::2] + [CD.income[-1], CD.house_price[-1], CD.rent_price[-1], CD.type_house[0],
                                 income_per_capita[0], CD.population[0], CD.race[1], CD.insurance[0], CD.households[-2]]
legend_selection = CD.legend_edu[-3::2]+[CD.legend_income[-1],CD.legend_house_price[-1], CD.legend_rent_price[-1],
    CD.legend_housetype[0], 'Income Per Capita',CD.legend_pop[0], CD.legend_race[1],CD.legend_insur[0], CD.legend_households[-2]]
CD.HighlightFeatures(Demo_NY, selection, P_CP4, legend_selection, 'Some features', by_feature=1)

# %% [markdown]
# ## D) Gravitional Test (notes cited from prof. Sobolevsky, NYU CUSP)

# %% [markdown]
# In this case nodes are given spatial coordinates, while edges, together with their network topology weight $e(a,b)$, can also be assigned their geographical distance $d(a,b)$. We'll refer to such network as "spatial networks".
#
# It is a common property for many spatial networks to have edge weight decay with distance (connections between more distant objects are weaker). This dependence is often thought as a power-law trend:
# $$
# e(a,b)\sim d(a,b)^{-\gamma}.
# $$
#
# However often nodes are not equal - for example in case of human mobility networks, where nodes are locations in space, while edges represent number of people moving between them, nodes might be of different size or different density. In this case one could also consider
# $$
# e(a,b)\sim w(a),\ e(a,b)\sim w(b),
# $$
# or more generally (keeping an idea of the power-law dependence and assuming under-/super-linear scaling of destination attractiveness or origin activity with size):
# $$
# e(a,b)\sim w(a)^\alpha,\ e(a,b)\sim w(b)^\beta.
# $$
# where $w(x)$ is the weight of the node $x$.
#
# ## Gravity model
#
# All together those relations lead to a model
# $$
# e(a,b)=k\cdot w(a) w(b) d(a,b)^{-\gamma},
# $$
# or more generally
# $$
# e(a,b)=k\cdot w(a)^\alpha w(b)^\beta d(a,b)^{-\gamma},
# $$
# where $k$ is the global proportionality (normalization) factor
# $$
# k=\frac{\sum\limits_{a,b}e(a,b)}{\sum\limits_{a,b} w(a)^\alpha w(b)^\beta d(a,b)^{-\gamma}}.
# $$
#
# In case network does not have loop edges to model, the normalization factor is defined as
# $$
# k=\frac{\sum\limits_{a\neq b}e(a,b)}{\sum\limits_{a\neq b} w(a)^\alpha w(b)^\beta d(a,b)^{-\gamma}}.
# $$
#
# Often it is reasonable to assume that $\alpha=\beta$ (especially if the network is symmetric, like representing number of people visiting both locations $a$ and $b$ regardless their order, or cumulative communication flux between the two locations regardless directionality).
#
# This model is called gravity model.
#
# ## Gravity model with local normalization
#
# Alternatively, one can also introduce local normalization, assuming relative scaling of strength of attractiveness of different destinations $b$ for the origin $a$ to be proportional to
# $$
# {\rm attr}_a(b)\sim w(b)^\beta d(a,b)^{-\gamma}.
# $$
# Given the known total outgoing strength $T(a)$ for each node $a$, this leads to the model
# $$
# e(a,b)=T(a) \frac{{\rm attr}_a(b)}{\sum_c {\rm attr}_a(c)}
# $$
# i.e.
# $$
# e(a,b)=T(a) \frac{w(b)^\beta d(a,b)^{-\gamma}}{\sum_c w(c)^\beta d(a,c)^{-\gamma}}.
# $$
# In case loop edges are missing in the network one should rather write
# $$
# e(a,b)=T(a) \frac{w(b)^\beta d(a,b)^{-\gamma}}{\sum_{c\neq a} w(c)^\beta d(a,c)^{-\gamma}},
# $$
# as the entire outgoing strength is to be distributed among the possible non-loop edges for $c\neq a$.
#
# ## Radiation model
#
# Another alternative approach to modelling spatial networks of human mobility and potentially interactions has been suggested in a recent paper [Simini, F., González, M. C., Maritan, A., & Barabási, A. L. (2012). A universal model for mobility and migration patterns. Nature, 484(7392)]. The key idea is that people select a closet destination bettan than the one they have in their location of origin according to a certain attractiveness distribution and the beauty of the model is that it gives a one single paramter-free formula (just based on the given population distribution, nothing to fit or assume unlike the exponents in the gravity model), no matter what the assumed attractiveness distribution was. The model however also relies on the knowledge of the cumulative outgoing strength of the nodes, just like the gravity model with the local normalization does.
#
# The model predicting mobility flux (an edge) $e(a,b)$ between two locations $a,b$ is
# $$
# e(a,b)=T(a)\frac{p(a)p(b)}{\left(p(a)+s(a,b)\right)\left(p(a)+p(b)+s(a,b)\right)},
# $$
# where $p(a)$ denotes the population of the location $a$, while $s(a,b)$ is the total population enclosed in the circle centered in $a$ with the radius equal to $d(a,b)$ (i.e. the total population residing no further from $a$ compared to $b$).

# %% [markdown]
# import scipy.stats as stat
# from scipy import optimize
# import statsmodels.formula.api as smf
# from geopy.distance import vincenty

# %%
import scipy.stats as stat
from scipy import optimize
import statsmodels.formula.api as smf
from geopy.distance import vincenty

# %%
def Dist_Centr_Comp1(NET_index, date_index = 0, centrality = 1, city_ziplist = CD.PLACES, ziplist = CD.USzipcode):
    '''
    First method, we extract zip codes' coordinates by simply using data from USzipcode.csv
    Centrality's options are
    1--degree centrality, the number of tweets captured at each zip code
    2--page rank centrality, calculated previously
    '''
    network = pd.DataFrame(Net1[date_index],copy = True) if NET_index == 1 else pd.DataFrame(Net2[date_index],copy = True)
    network.columns = ['zip1','zip2','weight']
    if NET_index ==1:
        a = pd.DataFrame(network,copy = True)
        b = a.loc[:,['zip2','zip1','weight']]
        b.columns = ['zip1','zip2','weight']
        network = a.append(b)
        network.index = range(len(network))
        
    leng = len(network)
    ziplist = ziplist[ziplist.ZipCode.isin(CD.PLACES)]
    zipdict = {int(ziplist.iloc[i,0]):(ziplist.iloc[i,1],ziplist.iloc[i,2]
                                      ) for i in range(len(ziplist))}
    temp = network.loc[:,['zip1','zip2']]
    distance = [vincenty(zipdict[network.zip1[i]], zipdict[network.zip2[i]]
                        ).miles for i in range(leng)]
    network['distance'] = distance
    if centrality == 1:
    #First choice of node centrality, the number of tweets captured in each zip code
        node_centrality = { i:sum(CD.Data[date_index].ZipCode == i
                                 )  for i in CD.Data[date_index].ZipCode.unique()}
        network['w1'] = [node_centrality[i] for i in network.zip1]
        network['w2'] = [node_centrality[i] for i in network.zip2]
    elif centrality == 2:
    #Page rank list
        node_centrality = PR1[date_index] if NET_index == 1 else PR2[date_index]
        network['w1'] = [node_centrality[i] for i in network.zip1]
        network['w2'] = [node_centrality[i] for i in network.zip2]
    
    return network

def LMComplexSummary(date_index, net_index, centrality_index, print_index = True, plot_index = False):
    if centrality_index == 1:
        data = Net1GravDegree[i].iloc[:,-4:] if net_index == 1 else Net2GravDegree[i].iloc[:,-4:]
    else:
        data = Net1GravPageRk[i].iloc[:,-4:] if net_index == 1 else Net2GravPageRk[i].iloc[:,-4:]
    data = data.loc[(data.distance > 0) & (data.weight > 0)]
    lm = smf.ols(formula='log(weight) ~ log(distance)+log(w1)+log(w2)', data = data).fit()
    Title = ['Naive Network','Probabilistic Network']
    if print_index:
        print(lm.summary())
    if plot_index:
        plt.subplot(237+4*net_index+date_index)
        lme = lm.predict(data)
        plt.plot(lme,log(data.weight),'or')
        plt.plot(lme,lme,'-b')
        plt.title(Title[net_index-1]+', '+LABEL[date_index]+'days')
        plt.xlabel('log(distance)')
        plt.ylabel('log(weight)+log(w1)+log(w2)')

def ValidationSummary(date_index, net_index, centrality_index, print_index = True, plot_index = False):
    if centrality_index == 1:
        data = Net1GravDegree[i].iloc[:,-4:] if net_index == 1 else Net2GravDegree[i].iloc[:,-4:]
    else:
        data = Net1GravPageRk[i].iloc[:,-4:] if net_index == 1 else Net2GravPageRk[i].iloc[:,-4:]
    data = data.loc[(data.distance > 0) & (data.weight > 0)]
    random.seed(2016)
    ind=stat.bernoulli.rvs(p = 0.67, size = len(data.weight))
    train=data.loc[ind==1]
    valid=data.loc[ind==0]

    lm = smf.ols(formula='log(weight) ~ log(distance)+log(w1)+log(w2)', data = train).fit()
    Title = ['Naive Network','Probabilistic Network']
    if print_index:
        print(lm.summary())
    if plot_index:
        plt.subplot(237+4*net_index+date_index)
        lme = lm.predict(valid)
        plt.plot(lme,log(valid.weight),'or')
        plt.plot(lme,lme,'-b')
        R2=1-sum(pow(log(valid.weight)-lme,2))/sum(pow(log(valid.weight)-mean(log(valid.weight)),2))
        plt.title(Title[net_index-1]+', '+LABEL[date_index]+'days\nValidation error=%f'%R2)
        #plt.xlabel('log(distance)')
        #plt.ylabel('log(weight)+log(w1)+log(w2)')

# %%
Net1GravDegree, Net2GravDegree = range(4), range(4)
Net1GravPageRk, Net2GravPageRk = range(4), range(4)
for i in range(4):
    Net1GravDegree[i].read_csv(PWD+'/GravModel/Net1Degree '+LABEL[i]+'days.csv')
    Net2GravDegree[i].read_csv(PWD+'/GravModel/Net2Degree '+LABEL[i]+'days.csv')
    Net1GravPageRk[i].read_csv(PWD+'/GravModel/Net1PageRk '+LABEL[i]+'days.csv')
    Net2GravPageRk[i].read_csv(PWD+'/GravModel/Net2PageRk '+LABEL[i]+'days.csv')

# %% [markdown]
# ## First let's see the degree centrality case

# %%
plt.figure(figsize= (20,9))
plt.suptitle('Degree Centrality, based on the number of tweets captured on each zip code', fontweight = 'bold',size = 18)
for i in range(4):
    LMComplexSummary(i,1,1,1,1)
    LMComplexSummary(i,2,1,1,1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                 5.024e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -39412.
# No. Observations:               40802   AIC:                         7.883e+04
# Df Residuals:                   40798   BIC:                         7.887e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -4.8010      0.022   -213.407      0.000        -4.845    -4.757
# log(distance)    -0.3839      0.004    -94.804      0.000        -0.392    -0.376
# log(w1)           0.5509      0.002    288.312      0.000         0.547     0.555
# log(w2)           0.5509      0.002    288.312      0.000         0.547     0.555
# ==============================================================================
# Omnibus:                      616.858   Durbin-Watson:                   1.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1103.585
# Skew:                          -0.095   Prob(JB):                    2.29e-240
# Kurtosis:                       3.783   Cond. No.                         73.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                 3.279e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -69677.
# No. Observations:               40802   AIC:                         1.394e+05
# Df Residuals:                   40798   BIC:                         1.394e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -24.9740      0.047   -528.719      0.000       -25.067   -24.881
# log(distance)    -0.7682      0.009    -90.345      0.000        -0.785    -0.752
# log(w1)           0.9208      0.004    229.528      0.000         0.913     0.929
# log(w2)           0.9208      0.004    229.528      0.000         0.913     0.929
# ==============================================================================
# Omnibus:                     2966.601   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6388.545
# Skew:                          -0.481   Prob(JB):                         0.00
# Kurtosis:                       4.683   Cond. No.                         73.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                 3.803e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -38135.
# No. Observations:               39412   AIC:                         7.628e+04
# Df Residuals:                   39408   BIC:                         7.631e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -4.1321      0.023   -181.046      0.000        -4.177    -4.087
# log(distance)    -0.3361      0.004    -81.217      0.000        -0.344    -0.328
# log(w1)           0.4999      0.002    249.294      0.000         0.496     0.504
# log(w2)           0.4999      0.002    249.294      0.000         0.496     0.504
# ==============================================================================
# Omnibus:                      321.757   Durbin-Watson:                   1.127
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.282
# Skew:                          -0.078   Prob(JB):                    1.39e-104
# Kurtosis:                       3.517   Cond. No.                         69.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                 2.530e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -70228.
# No. Observations:               39412   AIC:                         1.405e+05
# Df Residuals:                   39408   BIC:                         1.405e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -24.1813      0.052   -469.295      0.000       -24.282   -24.080
# log(distance)    -0.7713      0.009    -82.543      0.000        -0.790    -0.753
# log(w1)           0.9012      0.005    199.048      0.000         0.892     0.910
# log(w2)           0.9012      0.005    199.048      0.000         0.892     0.910
# ==============================================================================
# Omnibus:                     3845.849   Durbin-Watson:                   1.358
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7786.039
# Skew:                          -0.640   Prob(JB):                         0.00
# Kurtosis:                       4.762   Cond. No.                         69.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     9341.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -22780.
# No. Observations:               24604   AIC:                         4.557e+04
# Df Residuals:                   24600   BIC:                         4.560e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -1.8938      0.026    -71.603      0.000        -1.946    -1.842
# log(distance)    -0.2751      0.005    -52.736      0.000        -0.285    -0.265
# log(w1)           0.3227      0.003    113.844      0.000         0.317     0.328
# log(w2)           0.3227      0.003    113.844      0.000         0.317     0.328
# ==============================================================================
# Omnibus:                       98.280   Durbin-Watson:                   1.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.568
# Skew:                          -0.149   Prob(JB):                     3.95e-22
# Kurtosis:                       2.911   Cond. No.                         55.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     8082.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -45581.
# No. Observations:               24604   AIC:                         9.117e+04
# Df Residuals:                   24600   BIC:                         9.120e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -18.4360      0.067   -275.925      0.000       -18.567   -18.305
# log(distance)    -1.0048      0.013    -76.246      0.000        -1.031    -0.979
# log(w1)           0.6770      0.007     94.551      0.000         0.663     0.691
# log(w2)           0.6770      0.007     94.551      0.000         0.663     0.691
# ==============================================================================
# Omnibus:                      482.575   Durbin-Watson:                   1.549
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.210
# Skew:                          -0.347   Prob(JB):                    9.82e-112
# Kurtosis:                       3.126   Cond. No.                         55.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                 1.022e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -24253.
# No. Observations:               25368   AIC:                         4.851e+04
# Df Residuals:                   25364   BIC:                         4.855e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -2.0566      0.026    -78.891      0.000        -2.108    -2.006
# log(distance)    -0.2785      0.005    -52.587      0.000        -0.289    -0.268
# log(w1)           0.3340      0.003    122.209      0.000         0.329     0.339
# log(w2)           0.3340      0.003    122.209      0.000         0.329     0.339
# ==============================================================================
# Omnibus:                      148.906   Durbin-Watson:                   1.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.990
# Skew:                          -0.146   Prob(JB):                     1.09e-30
# Kurtosis:                       2.788   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.538
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     9856.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:26   Log-Likelihood:                -46451.
# No. Observations:               25368   AIC:                         9.291e+04
# Df Residuals:                   25364   BIC:                         9.294e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -19.3530      0.063   -309.452      0.000       -19.476   -19.230
# log(distance)    -0.9289      0.013    -73.123      0.000        -0.954    -0.904
# log(w1)           0.7344      0.007    112.006      0.000         0.722     0.747
# log(w2)           0.7344      0.007    112.006      0.000         0.722     0.747
# ==============================================================================
# Omnibus:                      278.042   Durbin-Watson:                   1.600
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.676
# Skew:                          -0.254   Prob(JB):                     3.40e-63
# Kurtosis:                       3.119   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Next let's see the page rank centrality case

# %%
plt.figure(figsize= (20,9))
plt.suptitle('Page Rank Centrality, calculated before', fontweight = 'bold',size = 18)
for i in range(4):
    LMComplexSummary(i,1,2,1,1)
    LMComplexSummary(i,2,2,1,1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                 3.546e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -44787.
# No. Observations:               40802   AIC:                         8.958e+04
# Df Residuals:                   40798   BIC:                         8.962e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        13.6308      0.036    382.844      0.000        13.561    13.701
# log(distance)    -0.1628      0.005    -34.618      0.000        -0.172    -0.154
# log(w1)           0.9714      0.004    240.064      0.000         0.963     0.979
# log(w2)           0.9714      0.004    240.064      0.000         0.963     0.979
# ==============================================================================
# Omnibus:                     4192.941   Durbin-Watson:                   0.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7078.047
# Skew:                          -0.729   Prob(JB):                         0.00
# Kurtosis:                       4.428   Cond. No.                         84.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.617
# Method:                 Least Squares   F-statistic:                 2.189e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -75140.
# No. Observations:               40802   AIC:                         1.503e+05
# Df Residuals:                   40798   BIC:                         1.503e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         4.8234      0.073     66.068      0.000         4.680     4.966
# log(distance)    -0.5712      0.010    -58.336      0.000        -0.590    -0.552
# log(w1)           1.4903      0.008    182.995      0.000         1.474     1.506
# log(w2)           1.4903      0.008    182.995      0.000         1.474     1.506
# ==============================================================================
# Omnibus:                     3148.895   Durbin-Watson:                   1.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4394.872
# Skew:                          -0.651   Prob(JB):                         0.00
# Kurtosis:                       3.943   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                 3.238e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -40442.
# No. Observations:               39412   AIC:                         8.089e+04
# Df Residuals:                   39408   BIC:                         8.093e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        12.6505      0.035    362.811      0.000        12.582    12.719
# log(distance)    -0.1716      0.004    -38.498      0.000        -0.180    -0.163
# log(w1)           0.9126      0.004    229.077      0.000         0.905     0.920
# log(w2)           0.9126      0.004    229.077      0.000         0.905     0.920
# ==============================================================================
# Omnibus:                     3423.937   Durbin-Watson:                   0.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5323.062
# Skew:                          -0.667   Prob(JB):                         0.00
# Kurtosis:                       4.209   Cond. No.                         87.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                 1.898e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -73771.
# No. Observations:               39412   AIC:                         1.476e+05
# Df Residuals:                   39408   BIC:                         1.476e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         4.4541      0.077     57.754      0.000         4.303     4.605
# log(distance)    -0.6139      0.010    -59.626      0.000        -0.634    -0.594
# log(w1)           1.4573      0.009    168.482      0.000         1.440     1.474
# log(w2)           1.4573      0.009    168.482      0.000         1.440     1.474
# ==============================================================================
# Omnibus:                     3311.449   Durbin-Watson:                   1.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4757.196
# Skew:                          -0.682   Prob(JB):                         0.00
# Kurtosis:                       4.019   Cond. No.                         83.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                 1.664e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -18498.
# No. Observations:               24604   AIC:                         3.700e+04
# Df Residuals:                   24600   BIC:                         3.704e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         9.3518      0.038    248.017      0.000         9.278     9.426
# log(distance)    -0.2684      0.004    -61.275      0.000        -0.277    -0.260
# log(w1)           0.7224      0.005    158.246      0.000         0.713     0.731
# log(w2)           0.7224      0.005    158.246      0.000         0.713     0.731
# ==============================================================================
# Omnibus:                      435.799   Durbin-Watson:                   1.383
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              485.258
# Skew:                          -0.294   Prob(JB):                    4.24e-106
# Kurtosis:                       3.357   Cond. No.                         92.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     8120.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -45552.
# No. Observations:               24604   AIC:                         9.111e+04
# Df Residuals:                   24600   BIC:                         9.114e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         0.8652      0.096      9.037      0.000         0.678     1.053
# log(distance)    -0.9768      0.013    -74.052      0.000        -1.003    -0.951
# log(w1)           1.0840      0.011     94.713      0.000         1.062     1.106
# log(w2)           1.0840      0.011     94.713      0.000         1.062     1.106
# ==============================================================================
# Omnibus:                      584.713   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              627.148
# Skew:                          -0.391   Prob(JB):                    6.55e-137
# Kurtosis:                       3.004   Cond. No.                         80.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                 1.624e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -20708.
# No. Observations:               25368   AIC:                         4.142e+04
# Df Residuals:                   25364   BIC:                         4.146e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         9.3912      0.038    245.323      0.000         9.316     9.466
# log(distance)    -0.2488      0.005    -53.902      0.000        -0.258    -0.240
# log(w1)           0.7258      0.005    159.438      0.000         0.717     0.735
# log(w2)           0.7258      0.005    159.438      0.000         0.717     0.735
# ==============================================================================
# Omnibus:                      417.099   Durbin-Watson:                   1.384
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              440.090
# Skew:                          -0.310   Prob(JB):                     2.73e-96
# Kurtosis:                       3.181   Cond. No.                         89.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     9170.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:34   Log-Likelihood:                -46936.
# No. Observations:               25368   AIC:                         9.388e+04
# Df Residuals:                   25364   BIC:                         9.391e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         1.7926      0.094     19.032      0.000         1.608     1.977
# log(distance)    -0.8791      0.013    -67.660      0.000        -0.905    -0.854
# log(w1)           1.1886      0.011    107.411      0.000         1.167     1.210
# log(w2)           1.1886      0.011    107.411      0.000         1.167     1.210
# ==============================================================================
# Omnibus:                      313.691   Durbin-Watson:                   1.554
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              325.057
# Skew:                          -0.276   Prob(JB):                     2.60e-71
# Kurtosis:                       2.952   Cond. No.                         80.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Display of validation error

# %%
plt.figure(figsize= (20,9))
plt.suptitle('Validation Error: Degree Centrality', fontweight = 'bold',size = 18)
for i in range(4):
    ValidationSummary(i,1,1,1,1)
    ValidationSummary(i,2,1,1,1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                 3.294e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -26431.
# No. Observations:               27308   AIC:                         5.287e+04
# Df Residuals:                   27304   BIC:                         5.290e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -4.8143      0.028   -173.950      0.000        -4.869    -4.760
# log(distance)    -0.3774      0.005    -75.480      0.000        -0.387    -0.368
# log(w1)           0.5503      0.002    233.976      0.000         0.546     0.555
# log(w2)           0.5513      0.002    235.659      0.000         0.547     0.556
# ==============================================================================
# Omnibus:                      398.874   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              690.008
# Skew:                          -0.105   Prob(JB):                    1.47e-150
# Kurtosis:                       3.750   Cond. No.                         73.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                 2.206e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -46668.
# No. Observations:               27308   AIC:                         9.334e+04
# Df Residuals:                   27304   BIC:                         9.338e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -24.9526      0.058   -432.322      0.000       -25.066   -24.840
# log(distance)    -0.7731      0.010    -74.112      0.000        -0.794    -0.753
# log(w1)           0.9215      0.005    188.009      0.000         0.912     0.931
# log(w2)           0.9180      0.005    187.437      0.000         0.908     0.928
# ==============================================================================
# Omnibus:                     1975.916   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4249.055
# Skew:                          -0.479   Prob(JB):                         0.00
# Kurtosis:                       4.678   Cond. No.                         72.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                 2.509e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -25559.
# No. Observations:               26335   AIC:                         5.113e+04
# Df Residuals:                   26331   BIC:                         5.116e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -4.1251      0.028   -147.218      0.000        -4.180    -4.070
# log(distance)    -0.3360      0.005    -66.122      0.000        -0.346    -0.326
# log(w1)           0.4980      0.002    202.383      0.000         0.493     0.503
# log(w2)           0.5002      0.002    203.257      0.000         0.495     0.505
# ==============================================================================
# Omnibus:                      202.066   Durbin-Watson:                   1.155
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.402
# Skew:                          -0.075   Prob(JB):                     4.34e-65
# Kurtosis:                       3.498   Cond. No.                         69.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                 1.708e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -46823.
# No. Observations:               26335   AIC:                         9.365e+04
# Df Residuals:                   26331   BIC:                         9.369e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -24.2038      0.063   -386.243      0.000       -24.327   -24.081
# log(distance)    -0.7787      0.011    -68.741      0.000        -0.801    -0.756
# log(w1)           0.9060      0.006    164.231      0.000         0.895     0.917
# log(w2)           0.9015      0.006    162.903      0.000         0.891     0.912
# ==============================================================================
# Omnibus:                     2529.406   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5119.031
# Skew:                          -0.631   Prob(JB):                         0.00
# Kurtosis:                       4.753   Cond. No.                         69.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     6233.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -15337.
# No. Observations:               16429   AIC:                         3.068e+04
# Df Residuals:                   16425   BIC:                         3.071e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -1.8933      0.033    -57.946      0.000        -1.957    -1.829
# log(distance)    -0.2820      0.006    -43.922      0.000        -0.295    -0.269
# log(w1)           0.3254      0.003     92.984      0.000         0.319     0.332
# log(w2)           0.3231      0.004     92.072      0.000         0.316     0.330
# ==============================================================================
# Omnibus:                       67.597   Durbin-Watson:                   1.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.965
# Skew:                          -0.152   Prob(JB):                     1.74e-15
# Kurtosis:                       2.917   Cond. No.                         55.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     5388.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -30460.
# No. Observations:               16429   AIC:                         6.093e+04
# Df Residuals:                   16425   BIC:                         6.096e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -18.4214      0.082   -225.240      0.000       -18.582   -18.261
# log(distance)    -0.9962      0.016    -61.438      0.000        -1.028    -0.964
# log(w1)           0.6749      0.009     77.059      0.000         0.658     0.692
# log(w2)           0.6755      0.009     77.434      0.000         0.658     0.693
# ==============================================================================
# Omnibus:                      335.148   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.926
# Skew:                          -0.353   Prob(JB):                     5.15e-78
# Kurtosis:                       3.149   Cond. No.                         55.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.547
# Method:                 Least Squares   F-statistic:                     6811.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -16121.
# No. Observations:               16941   AIC:                         3.225e+04
# Df Residuals:                   16937   BIC:                         3.228e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        -2.0460      0.032    -64.576      0.000        -2.108    -1.984
# log(distance)    -0.2765      0.006    -42.801      0.000        -0.289    -0.264
# log(w1)           0.3324      0.003    100.234      0.000         0.326     0.339
# log(w2)           0.3334      0.003     99.890      0.000         0.327     0.340
# ==============================================================================
# Omnibus:                       95.667   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.747
# Skew:                          -0.143   Prob(JB):                     5.36e-20
# Kurtosis:                       2.791   Cond. No.                         54.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     6705.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -31036.
# No. Observations:               16941   AIC:                         6.208e+04
# Df Residuals:                   16937   BIC:                         6.211e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept       -19.3509      0.076   -255.373      0.000       -19.499   -19.202
# log(distance)    -0.9374      0.015    -60.674      0.000        -0.968    -0.907
# log(w1)           0.7357      0.008     91.797      0.000         0.720     0.751
# log(w2)           0.7360      0.008     92.626      0.000         0.720     0.752
# ==============================================================================
# Omnibus:                      165.087   Durbin-Watson:                   1.623
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.104
# Skew:                          -0.239   Prob(JB):                     1.15e-37
# Kurtosis:                       3.113   Cond. No.                         53.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.figure(figsize= (20,9))
plt.suptitle('Validation Error: Page Rank Centrality', fontweight = 'bold',size = 18)
for i in range(4):
    ValidationSummary(i,1,2,1,1)
    ValidationSummary(i,2,2,1,1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                 2.286e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:46   Log-Likelihood:                -30175.
# No. Observations:               27308   AIC:                         6.036e+04
# Df Residuals:                   27304   BIC:                         6.039e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        13.5555      0.044    307.830      0.000        13.469    13.642
# log(distance)    -0.1533      0.006    -26.268      0.000        -0.165    -0.142
# log(w1)           0.9643      0.005    193.180      0.000         0.954     0.974
# log(w2)           0.9692      0.005    194.635      0.000         0.959     0.979
# ==============================================================================
# Omnibus:                     2772.620   Durbin-Watson:                   0.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4586.278
# Skew:                          -0.729   Prob(JB):                         0.00
# Kurtosis:                       4.380   Cond. No.                         85.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                 1.487e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -50253.
# No. Observations:               27308   AIC:                         1.005e+05
# Df Residuals:                   27304   BIC:                         1.005e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         4.8149      0.089     54.374      0.000         4.641     4.989
# log(distance)    -0.5760      0.012    -48.064      0.000        -0.600    -0.553
# log(w1)           1.4895      0.010    150.338      0.000         1.470     1.509
# log(w2)           1.4887      0.010    150.199      0.000         1.469     1.508
# ==============================================================================
# Omnibus:                     2084.559   Durbin-Watson:                   1.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2900.228
# Skew:                          -0.647   Prob(JB):                         0.00
# Kurtosis:                       3.936   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                 2.147e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -27047.
# No. Observations:               26335   AIC:                         5.410e+04
# Df Residuals:                   26331   BIC:                         5.414e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        12.6452      0.043    295.397      0.000        12.561    12.729
# log(distance)    -0.1714      0.005    -31.377      0.000        -0.182    -0.161
# log(w1)           0.9083      0.005    186.486      0.000         0.899     0.918
# log(w2)           0.9169      0.005    187.113      0.000         0.907     0.926
# ==============================================================================
# Omnibus:                     2225.866   Durbin-Watson:                   0.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3394.456
# Skew:                          -0.660   Prob(JB):                         0.00
# Kurtosis:                       4.163   Cond. No.                         87.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.593
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                 1.278e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -49217.
# No. Observations:               26335   AIC:                         9.844e+04
# Df Residuals:                   26331   BIC:                         9.847e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         4.4759      0.094     47.635      0.000         4.292     4.660
# log(distance)    -0.6200      0.012    -49.651      0.000        -0.644    -0.596
# log(w1)           1.4627      0.011    139.025      0.000         1.442     1.483
# log(w2)           1.4533      0.011    137.630      0.000         1.433     1.474
# ==============================================================================
# Omnibus:                     2246.922   Durbin-Watson:                   1.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3244.955
# Skew:                          -0.687   Prob(JB):                         0.00
# Kurtosis:                       4.034   Cond. No.                         83.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                 1.108e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -12490.
# No. Observations:               16429   AIC:                         2.499e+04
# Df Residuals:                   16425   BIC:                         2.502e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         9.3969      0.046    202.138      0.000         9.306     9.488
# log(distance)    -0.2743      0.005    -50.830      0.000        -0.285    -0.264
# log(w1)           0.7260      0.006    129.200      0.000         0.715     0.737
# log(w2)           0.7245      0.006    128.085      0.000         0.713     0.736
# ==============================================================================
# Omnibus:                      311.908   Durbin-Watson:                   1.381
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              348.714
# Skew:                          -0.305   Prob(JB):                     1.90e-76
# Kurtosis:                       3.371   Cond. No.                         92.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     5418.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -30437.
# No. Observations:               16429   AIC:                         6.088e+04
# Df Residuals:                   16425   BIC:                         6.091e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         0.8580      0.117      7.339      0.000         0.629     1.087
# log(distance)    -0.9635      0.016    -59.347      0.000        -0.995    -0.932
# log(w1)           1.0825      0.014     77.235      0.000         1.055     1.110
# log(w2)           1.0868      0.014     77.752      0.000         1.059     1.114
# ==============================================================================
# Omnibus:                      394.840   Durbin-Watson:                   1.587
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              423.650
# Skew:                          -0.393   Prob(JB):                     1.01e-92
# Kurtosis:                       3.012   Cond. No.                         80.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                 1.084e+04
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -13749.
# No. Observations:               16941   AIC:                         2.751e+04
# Df Residuals:                   16937   BIC:                         2.754e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         9.3631      0.047    200.686      0.000         9.272     9.455
# log(distance)    -0.2467      0.006    -43.813      0.000        -0.258    -0.236
# log(w1)           0.7225      0.006    130.662      0.000         0.712     0.733
# log(w2)           0.7243      0.006    130.421      0.000         0.713     0.735
# ==============================================================================
# Omnibus:                      280.157   Durbin-Watson:                   1.431
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              296.000
# Skew:                          -0.309   Prob(JB):                     5.30e-65
# Kurtosis:                       3.194   Cond. No.                         89.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log(weight)   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     6278.
# Date:                Sun, 03 Apr 2016   Prob (F-statistic):               0.00
# Time:                        21:02:47   Log-Likelihood:                -31334.
# No. Observations:               16941   AIC:                         6.268e+04
# Df Residuals:                   16937   BIC:                         6.271e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         1.8803      0.114     16.435      0.000         1.656     2.105
# log(distance)    -0.8837      0.016    -56.005      0.000        -0.915    -0.853
# log(w1)           1.1919      0.014     88.229      0.000         1.165     1.218
# log(w2)           1.1993      0.013     89.337      0.000         1.173     1.226
# ==============================================================================
# Omnibus:                      184.130   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.023
# Skew:                          -0.259   Prob(JB):                     5.46e-42
# Kurtosis:                       2.972   Cond. No.                         80.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Notes: Since all of our networks are "symmetric", i.e. weight of link(a,b) = weight of link(b,a), thus their coefficients (the ones of $log(w_1)$ and $log(w_2)$) here are highly symmetric as well.
